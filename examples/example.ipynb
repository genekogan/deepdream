# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('..')

from model import *
from dream import *

params = DeepDreamArgs()
params.tile_size = 512
params.model_file = '../model/tensorflow_inception_graph.pb'

deepdream = DeepDream(params)
# Out:
# /home/bzion/.local/share/virtualenvs/neural-synth--cEg-8mZ/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/bzion/.local/share/virtualenvs/neural-synth--cEg-8mZ/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/bzion/.local/share/virtualenvs/neural-synth--cEg-8mZ/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/bzion/.local/share/virtualenvs/neural-synth--cEg-8mZ/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/bzion/.local/share/virtualenvs/neural-synth--cEg-8mZ/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/bzion/.local/share/virtualenvs/neural-synth--cEg-8mZ/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# WARNING:tensorflow:From ../model.py:39: FastGFile.__init__ (from tensorflow.python.platform.gfile) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.gfile.GFile.
# Number of layers 59
# Total number of feature channels: 7548
#  import/conv2d0_pre_relu/conv (64)
#  import/conv2d1_pre_relu/conv (64)
#  import/conv2d2_pre_relu/conv (192)
#  import/mixed3a_1x1_pre_relu/conv (64)
#  import/mixed3a_3x3_bottleneck_pre_relu/conv (96)
#  import/mixed3a_3x3_pre_relu/conv (128)
#  import/mixed3a_5x5_bottleneck_pre_relu/conv (16)
#  import/mixed3a_5x5_pre_relu/conv (32)
#  import/mixed3a_pool_reduce_pre_relu/conv (32)
#  import/mixed3b_1x1_pre_relu/conv (128)
#  import/mixed3b_3x3_bottleneck_pre_relu/conv (128)
#  import/mixed3b_3x3_pre_relu/conv (192)
#  import/mixed3b_5x5_bottleneck_pre_relu/conv (32)
#  import/mixed3b_5x5_pre_relu/conv (96)
#  import/mixed3b_pool_reduce_pre_relu/conv (64)
#  import/mixed4a_1x1_pre_relu/conv (192)
#  import/mixed4a_3x3_bottleneck_pre_relu/conv (96)
#  import/mixed4a_3x3_pre_relu/conv (204)
#  import/mixed4a_5x5_bottleneck_pre_relu/conv (16)
#  import/mixed4a_5x5_pre_relu/conv (48)
#  import/mixed4a_pool_reduce_pre_relu/conv (64)
#  import/mixed4b_1x1_pre_relu/conv (160)
#  import/mixed4b_3x3_bottleneck_pre_relu/conv (112)
#  import/mixed4b_3x3_pre_relu/conv (224)
#  import/mixed4b_5x5_bottleneck_pre_relu/conv (24)
#  import/mixed4b_5x5_pre_relu/conv (64)
#  import/mixed4b_pool_reduce_pre_relu/conv (64)
#  import/mixed4c_1x1_pre_relu/conv (128)
#  import/mixed4c_3x3_bottleneck_pre_relu/conv (128)
#  import/mixed4c_3x3_pre_relu/conv (256)
#  import/mixed4c_5x5_bottleneck_pre_relu/conv (24)
#  import/mixed4c_5x5_pre_relu/conv (64)
#  import/mixed4c_pool_reduce_pre_relu/conv (64)
#  import/mixed4d_1x1_pre_relu/conv (112)
#  import/mixed4d_3x3_bottleneck_pre_relu/conv (144)
#  import/mixed4d_3x3_pre_relu/conv (288)
#  import/mixed4d_5x5_bottleneck_pre_relu/conv (32)
#  import/mixed4d_5x5_pre_relu/conv (64)
#  import/mixed4d_pool_reduce_pre_relu/conv (64)
#  import/mixed4e_1x1_pre_relu/conv (256)
#  import/mixed4e_3x3_bottleneck_pre_relu/conv (160)
#  import/mixed4e_3x3_pre_relu/conv (320)
#  import/mixed4e_5x5_bottleneck_pre_relu/conv (32)
#  import/mixed4e_5x5_pre_relu/conv (128)
#  import/mixed4e_pool_reduce_pre_relu/conv (128)
#  import/mixed5a_1x1_pre_relu/conv (256)
#  import/mixed5a_3x3_bottleneck_pre_relu/conv (160)
#  import/mixed5a_3x3_pre_relu/conv (320)
#  import/mixed5a_5x5_bottleneck_pre_relu/conv (48)
#  import/mixed5a_5x5_pre_relu/conv (128)
#  import/mixed5a_pool_reduce_pre_relu/conv (128)
#  import/mixed5b_1x1_pre_relu/conv (384)
#  import/mixed5b_3x3_bottleneck_pre_relu/conv (192)
#  import/mixed5b_3x3_pre_relu/conv (384)
#  import/mixed5b_5x5_bottleneck_pre_relu/conv (48)
#  import/mixed5b_5x5_pre_relu/conv (128)
#  import/mixed5b_pool_reduce_pre_relu/conv (128)
#  import/head0_bottleneck_pre_relu/conv (128)
#  import/head1_bottleneck_pre_relu/conv (128)

# %%
config = {
    'objective': [
        {'layer': 'mixed4c_pool_reduce', 'channel': 61},
        {'layer': 'mixed4d_3x3_bottleneck_pre_relu', 'channel': 22}
    ],
    'num_octaves': 5,
    'octave_ratio': 1.333,
    'num_iterations': 32,
    'lap_n': 5,
    'masks': ['../../neural-style-pt/images/masks/monalisa1a.png',
              '../../neural-style-pt/images/masks/monalisa1b.png'],
    'step': 1.25,
    'size': 512,
    'grayscale_gradients': False,
    'normalize_gradients': True
}


img = load_image('../../neural-style-pt/images/inputs/monalisa.jpg', 64) #random_image((2048, 2048))
img = run_deepdream(deepdream, config, img)
display(img)
save(img, 'media/output.png')
# Out:
# <PIL.Image.Image image mode=RGB size=336x512 at 0x7F325C5C5E48>
